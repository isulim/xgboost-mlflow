# %% [markdown]
# # Download data

# %% [markdown]
# ##### Please run make configure-envs before running this notebook, as it is an interactive script.

# %%
# !make -C .. download-data
# Out:
# poetry run python scripts/data/01_download_data.py
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 .kaggle/kaggle.json'
# Download start...
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 .kaggle/kaggle.json'
# Dataset URL: https://www.kaggle.com/datasets/meirnizri/covid19-dataset
# Downloading covid19-dataset.zip to data/raw
#  64%|████████████████████████▍             | 3.00M/4.66M [00:00<00:00, 4.82MB/s]
# 100%|██████████████████████████████████████| 4.66M/4.66M [00:00<00:00, 5.84MB/s]
# Files downloaded successfully.
# Unzipping files...
# Unzipping all files...
# Unzipped all files.
# Deleted zip file.
# Output CSV stored in: data/raw/covid_data.csv
# Files unzipped successfully.

# %%
import os
from pathlib import Path

from dotenv import load_dotenv

load_dotenv()
root_data = os.getenv("KAGGLE_FILES_DIR")
dataset_path = Path(os.getcwd(), "..", root_data)
raw = Path(dataset_path, "raw")

# %% [markdown]
# # About dataset
# ### (from Kaggle)
#
# The main goal of this project is to build a machine learning model that, given a Covid-19 patient's current symptom, status, and medical history, will predict whether the patient is in high risk or not.
#
# ## Content
#
# The dataset was provided by the Mexican government.
# This dataset contains an enormous number of anonymized patient-related information including pre-conditions.
# The raw dataset consists of 21 unique features and 1,048,576 unique patients.  In the Boolean features, 1 means "yes" and 2 means "no". values as 97 and 99 are missing data.
#
# - sex: 1 for female and 2 for male.
# - age: of the patient.
# - classification: covid test findings. Values 1-3 mean that the patient was diagnosed with covid in different
# - degrees. 4 or higher means that the patient is not a carrier of covid or that the test is inconclusive.
# - patient type: type of care the patient received in the unit. 1 for returned home and 2 for hospitalization.
# - pneumonia: whether the patient already have air sacs inflammation or not.
# - pregnancy: whether the patient is pregnant or not.
# - diabetes: whether the patient has diabetes or not.
# - copd: Indicates whether the patient has Chronic obstructive pulmonary disease or not.
# - asthma: whether the patient has asthma or not.
# - inmsupr: whether the patient is immunosuppressed or not.
# - hypertension: whether the patient has hypertension or not.
# - cardiovascular: whether the patient has heart or blood vessels related disease.
# - renal chronic: whether the patient has chronic renal disease or not.
# - other disease: whether the patient has other disease or not.
# - obesity: whether the patient is obese or not.
# - tobacco: whether the patient is a tobacco user.
# - usmr: Indicates whether the patient treated medical units of the first, second or third level.
# - medical unit: type of institution of the National Health System that provided the care.
# - intubed: whether the patient was connected to the ventilator.
# - icu: Indicates whether the patient had been admitted to an Intensive Care Unit.
# - date died: If the patient died indicate the date of death, and 9999-99-99 otherwise.

# %% [markdown]
# ## Exploratory analysis

# %%
import pandas as pd

# %%
df = pd.read_csv(Path(raw, "covid_data.csv"))
print(f"Shape: {df.shape}")
df.head()
# Out:
# Shape: (1048575, 21)
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
# 2      2             1    2             2  09/06/2020        1          2
# 3      2             1    1             1  12/06/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
# 2   55        97         1  ...       2        2             2              2
# 3   53         2         2  ...       2        2             2              2
# 4   68        97         1  ...       2        2             1              2
#
#    CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL  ICU
# 0               2        2              2        2                     3   97
# 1               2        1              1        2                     5   97
# 2               2        2              2        2                     3    2
# 3               2        2              2        2                     7   97
# 4               2        2              2        2                     3   97
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Info about Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  int64
#  3   PATIENT_TYPE          1048575 non-null  int64
#  4   DATE_DIED             1048575 non-null  object
#  5   INTUBED               1048575 non-null  int64
#  6   PNEUMONIA             1048575 non-null  int64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              1048575 non-null  int64
#  9   DIABETES              1048575 non-null  int64
#  10  COPD                  1048575 non-null  int64
#  11  ASTHMA                1048575 non-null  int64
#  12  INMSUPR               1048575 non-null  int64
#  13  HIPERTENSION          1048575 non-null  int64
#  14  OTHER_DISEASE         1048575 non-null  int64
#  15  CARDIOVASCULAR        1048575 non-null  int64
#  16  OBESITY               1048575 non-null  int64
#  17  RENAL_CHRONIC         1048575 non-null  int64
#  18  TOBACCO               1048575 non-null  int64
#  19  CLASIFFICATION_FINAL  1048575 non-null  int64
#  20  ICU                   1048575 non-null  int64
# dtypes: int64(20), object(1)
# memory usage: 168.0+ MB

# %% [markdown]
# ##### Check for null values:

# %%
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ##### No null values, which is good, but there are missing data (values 97, 99).
#
# Check how many unique values are in each column.

# %%
for i in df.columns:
    print(i, "=>", len(df[i].unique()))
# Out:
# USMER => 2
# MEDICAL_UNIT => 13
# SEX => 2
# PATIENT_TYPE => 2
# DATE_DIED => 401
# INTUBED => 4
# PNEUMONIA => 3
# AGE => 121
# PREGNANT => 4
# DIABETES => 3
# COPD => 3
# ASTHMA => 3
# INMSUPR => 3
# HIPERTENSION => 3
# OTHER_DISEASE => 3
# CARDIOVASCULAR => 3
# OBESITY => 3
# RENAL_CHRONIC => 3
# TOBACCO => 3
# CLASIFFICATION_FINAL => 7
# ICU => 4

# %% [markdown]
# ##### Check for missing values:

# %%
for col in df.columns:
    print(f'{col} => {(len(df[(df[col] == 98) | (df[col] == 99) | (df[col] == 97)]) / len(df) * 100):.2f}%')
# Out:
# USMER => 0.00%
# MEDICAL_UNIT => 0.00%
# SEX => 0.00%
# PATIENT_TYPE => 0.00%
# DATE_DIED => 0.00%
# INTUBED => 81.62%
# PNEUMONIA => 1.53%
# AGE => 0.03%
# PREGNANT => 50.28%
# DIABETES => 0.32%
# COPD => 0.29%
# ASTHMA => 0.28%
# INMSUPR => 0.32%
# HIPERTENSION => 0.30%
# OTHER_DISEASE => 0.48%
# CARDIOVASCULAR => 0.29%
# OBESITY => 0.29%
# RENAL_CHRONIC => 0.29%
# TOBACCO => 0.31%
# CLASIFFICATION_FINAL => 0.00%
# ICU => 81.64%

# %% [markdown]
# ##### Remove missing values in columns with < 1% missing.
# Also "ICU" and "INTUBED" will totally be dropped, as these have over 80% missing values.
# "PREGNANT" needs evaluation.

# %%
df = df[(df.PNEUMONIA == 1) | (df.PNEUMONIA == 2)]
df = df[(df.DIABETES == 1) | (df.DIABETES == 2)]
df = df[(df.COPD == 1) | (df.COPD == 2)]
df = df[(df.ASTHMA == 1) | (df.ASTHMA == 2)]
df = df[(df.INMSUPR == 1) | (df.INMSUPR == 2)]
df = df[(df.HIPERTENSION == 1) | (df.HIPERTENSION == 2)]
df = df[(df.OTHER_DISEASE == 1) | (df.OTHER_DISEASE == 2)]
df = df[(df.CARDIOVASCULAR == 1) | (df.CARDIOVASCULAR == 2)]
df = df[(df.OBESITY == 1) | (df.OBESITY == 2)]
df = df[(df.RENAL_CHRONIC == 1) | (df.RENAL_CHRONIC == 2)]
df = df[(df.TOBACCO == 1) | (df.TOBACCO == 2)]
df.drop(columns=["INTUBED", "ICU"], inplace=True)

# %%
df.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  PNEUMONIA  AGE  \
# 0      2             1    1             1  03/05/2020          1   65
# 1      2             1    2             1  03/06/2020          1   72
# 2      2             1    2             2  09/06/2020          2   55
# 3      2             1    1             1  12/06/2020          2   53
# 4      2             1    2             1  21/06/2020          2   68
#
#    PREGNANT  DIABETES  COPD  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0         2         2     2       2        2             1              2
# 1        97         2     2       2        2             1              2
# 2        97         1     2       2        2             2              2
# 3         2         2     2       2        2             2              2
# 4        97         1     2       2        2             1              2
#
#    CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL
# 0               2        2              2        2                     3
# 1               2        1              1        2                     5
# 2               2        2              2        2                     3
# 3               2        2              2        2                     7
# 4               2        2              2        2                     3

# %% [markdown]
# Column "DATE_DIED" has value 9999-99-99 meaning patient has not died.
# Dead patient will be marked as 2, living as 1.
# Column "DEATH" will be target in classification.

# %%
df["DEATH"] = [1 if each == "9999-99-99" else 2 for each in df.DATE_DIED]
df.drop(columns=["DATE_DIED"], inplace=True)

# %% [markdown]
# Investigate column "PREGNANT" with "SEX"
#
# Check if male sex (2) has any non-missing values for pregnancy.

# %%
df.loc[df["SEX"] == 2, "PREGNANT"].unique()
# Out:
# array([97])

# %% [markdown]
# All males have missing value (97) for pregnancy -> it will be marked as 2 (non-pregnant).

# %%
df.loc[df["SEX"] == 1, "PREGNANT"].unique()
# Out:
# array([ 2, 98,  1])

# %% [markdown]
# Females have another missing value (98) for pregnancy -> it will be marked removed.

# %%
df["PREGNANT"] = df["PREGNANT"].replace(97, 2)
# Removing missing values
df = df[(df.PREGNANT == 1) | (df.PREGNANT == 2)]

# %%
df.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  PNEUMONIA  AGE  PREGNANT  DIABETES  \
# 0      2             1    1             1          1   65         2         2
# 1      2             1    2             1          1   72         2         2
# 2      2             1    2             2          2   55         2         1
# 3      2             1    1             1          2   53         2         2
# 4      2             1    2             1          2   68         2         1
#
#    COPD  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  CARDIOVASCULAR  \
# 0     2       2        2             1              2               2
# 1     2       2        2             1              2               2
# 2     2       2        2             2              2               2
# 3     2       2        2             2              2               2
# 4     2       2        2             1              2               2
#
#    OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL  DEATH
# 0        2              2        2                     3      2
# 1        1              1        2                     5      2
# 2        2              2        2                     3      2
# 3        2              2        2                     7      2
# 4        2              2        2                     3      2

# %% [markdown]
# Check unique values again:

# %%
for i in df.columns:
    print(i, "=>", len(df[i].unique()))
# Out:
# USMER => 2
# MEDICAL_UNIT => 13
# SEX => 2
# PATIENT_TYPE => 2
# PNEUMONIA => 2
# AGE => 121
# PREGNANT => 2
# DIABETES => 2
# COPD => 2
# ASTHMA => 2
# INMSUPR => 2
# HIPERTENSION => 2
# OTHER_DISEASE => 2
# CARDIOVASCULAR => 2
# OBESITY => 2
# RENAL_CHRONIC => 2
# TOBACCO => 2
# CLASIFFICATION_FINAL => 7
# DEATH => 2

# %% [markdown]
# Draw correlation map between columns.

# %%
corr = df.corr()
corr.style.background_gradient(cmap="coolwarm").format(precision=2)
# Out:
# <style type="text/css">
# #T_6e4a4_row0_col0, #T_6e4a4_row1_col1, #T_6e4a4_row2_col2, #T_6e4a4_row3_col3, #T_6e4a4_row4_col4, #T_6e4a4_row5_col5, #T_6e4a4_row6_col6, #T_6e4a4_row7_col7, #T_6e4a4_row8_col8, #T_6e4a4_row9_col9, #T_6e4a4_row10_col10, #T_6e4a4_row11_col11, #T_6e4a4_row12_col12, #T_6e4a4_row13_col13, #T_6e4a4_row14_col14, #T_6e4a4_row15_col15, #T_6e4a4_row16_col16, #T_6e4a4_row17_col17, #T_6e4a4_row18_col18 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6e4a4_row0_col1, #T_6e4a4_row0_col3, #T_6e4a4_row2_col11, #T_6e4a4_row17_col3 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_6e4a4_row0_col2, #T_6e4a4_row0_col14, #T_6e4a4_row3_col16, #T_6e4a4_row8_col2, #T_6e4a4_row11_col2, #T_6e4a4_row18_col16 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_6e4a4_row0_col4 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_6e4a4_row0_col5, #T_6e4a4_row0_col18, #T_6e4a4_row2_col7, #T_6e4a4_row7_col3, #T_6e4a4_row11_col8, #T_6e4a4_row15_col18 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_6e4a4_row0_col6, #T_6e4a4_row1_col6, #T_6e4a4_row3_col9, #T_6e4a4_row9_col6, #T_6e4a4_row10_col6, #T_6e4a4_row11_col9, #T_6e4a4_row12_col9, #T_6e4a4_row18_col14 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_6e4a4_row0_col7, #T_6e4a4_row9_col11, #T_6e4a4_row16_col11 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_6e4a4_row0_col8, #T_6e4a4_row8_col5, #T_6e4a4_row12_col17, #T_6e4a4_row14_col16 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_6e4a4_row0_col9, #T_6e4a4_row3_col13, #T_6e4a4_row18_col15 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_6e4a4_row0_col10, #T_6e4a4_row1_col2, #T_6e4a4_row2_col14, #T_6e4a4_row6_col12, #T_6e4a4_row9_col12, #T_6e4a4_row10_col14, #T_6e4a4_row15_col14, #T_6e4a4_row16_col12 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_6e4a4_row0_col11, #T_6e4a4_row8_col7, #T_6e4a4_row17_col7 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_6e4a4_row0_col12, #T_6e4a4_row1_col14, #T_6e4a4_row2_col12, #T_6e4a4_row4_col16, #T_6e4a4_row5_col1, #T_6e4a4_row7_col16, #T_6e4a4_row9_col10, #T_6e4a4_row10_col16, #T_6e4a4_row11_col16, #T_6e4a4_row12_col16, #T_6e4a4_row14_col12 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_6e4a4_row0_col13, #T_6e4a4_row4_col12, #T_6e4a4_row6_col8, #T_6e4a4_row8_col10, #T_6e4a4_row9_col2, #T_6e4a4_row9_col13, #T_6e4a4_row18_col11 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_6e4a4_row0_col15, #T_6e4a4_row9_col0, #T_6e4a4_row14_col0, #T_6e4a4_row14_col13, #T_6e4a4_row16_col1, #T_6e4a4_row18_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_6e4a4_row0_col16, #T_6e4a4_row6_col16, #T_6e4a4_row17_col10 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_6e4a4_row0_col17, #T_6e4a4_row10_col1, #T_6e4a4_row10_col12 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_6e4a4_row1_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_6e4a4_row1_col3, #T_6e4a4_row4_col1, #T_6e4a4_row13_col18 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_6e4a4_row1_col4 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_6e4a4_row1_col5, #T_6e4a4_row1_col18, #T_6e4a4_row14_col5 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_6e4a4_row1_col7, #T_6e4a4_row2_col5 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_6e4a4_row1_col8, #T_6e4a4_row3_col2, #T_6e4a4_row6_col1, #T_6e4a4_row6_col2, #T_6e4a4_row7_col18, #T_6e4a4_row8_col17, #T_6e4a4_row9_col8, #T_6e4a4_row12_col8, #T_6e4a4_row12_col13, #T_6e4a4_row12_col15, #T_6e4a4_row13_col0, #T_6e4a4_row13_col17, #T_6e4a4_row14_col8, #T_6e4a4_row17_col5 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_6e4a4_row1_col9, #T_6e4a4_row13_col9, #T_6e4a4_row18_col9, #T_6e4a4_row18_col12 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_6e4a4_row1_col10, #T_6e4a4_row3_col11, #T_6e4a4_row5_col0, #T_6e4a4_row18_col4 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_6e4a4_row1_col11 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_6e4a4_row1_col12, #T_6e4a4_row15_col0, #T_6e4a4_row17_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_6e4a4_row1_col13, #T_6e4a4_row2_col8 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_6e4a4_row1_col15, #T_6e4a4_row7_col14, #T_6e4a4_row8_col15, #T_6e4a4_row13_col5, #T_6e4a4_row17_col18 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_6e4a4_row1_col16, #T_6e4a4_row7_col2, #T_6e4a4_row13_col2, #T_6e4a4_row18_col7 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_6e4a4_row1_col17, #T_6e4a4_row7_col1, #T_6e4a4_row11_col17, #T_6e4a4_row13_col8 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_6e4a4_row2_col0 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_6e4a4_row2_col1, #T_6e4a4_row8_col0, #T_6e4a4_row12_col0, #T_6e4a4_row15_col17 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_6e4a4_row2_col3 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_6e4a4_row2_col4, #T_6e4a4_row17_col11 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_6e4a4_row2_col6, #T_6e4a4_row2_col17, #T_6e4a4_row7_col12, #T_6e4a4_row8_col14, #T_6e4a4_row12_col2 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_6e4a4_row2_col9, #T_6e4a4_row14_col9, #T_6e4a4_row18_col0 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_6e4a4_row2_col10, #T_6e4a4_row16_col10 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_6e4a4_row2_col13, #T_6e4a4_row6_col13, #T_6e4a4_row14_col2, #T_6e4a4_row15_col16 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_6e4a4_row2_col15, #T_6e4a4_row5_col2, #T_6e4a4_row8_col12, #T_6e4a4_row13_col16 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_6e4a4_row2_col16, #T_6e4a4_row3_col0, #T_6e4a4_row3_col1, #T_6e4a4_row3_col4, #T_6e4a4_row3_col10, #T_6e4a4_row3_col12, #T_6e4a4_row3_col15, #T_6e4a4_row4_col3, #T_6e4a4_row4_col18, #T_6e4a4_row5_col7, #T_6e4a4_row5_col8, #T_6e4a4_row5_col11, #T_6e4a4_row5_col13, #T_6e4a4_row5_col14, #T_6e4a4_row11_col5, #T_6e4a4_row11_col6, #T_6e4a4_row16_col2, #T_6e4a4_row17_col9, #T_6e4a4_row18_col17 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6e4a4_row2_col18, #T_6e4a4_row15_col7 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_6e4a4_row3_col5, #T_6e4a4_row17_col4, #T_6e4a4_row18_col5 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_6e4a4_row3_col6, #T_6e4a4_row3_col14, #T_6e4a4_row4_col2, #T_6e4a4_row8_col6, #T_6e4a4_row13_col6, #T_6e4a4_row15_col6, #T_6e4a4_row16_col9, #T_6e4a4_row17_col6 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_6e4a4_row3_col7 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_6e4a4_row3_col8, #T_6e4a4_row5_col9, #T_6e4a4_row5_col15, #T_6e4a4_row17_col2 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_6e4a4_row3_col17, #T_6e4a4_row4_col9, #T_6e4a4_row7_col6 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_6e4a4_row3_col18 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_6e4a4_row4_col0, #T_6e4a4_row10_col7, #T_6e4a4_row10_col18, #T_6e4a4_row11_col15 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_6e4a4_row4_col5, #T_6e4a4_row5_col16, #T_6e4a4_row6_col10, #T_6e4a4_row15_col2, #T_6e4a4_row17_col12 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_6e4a4_row4_col6, #T_6e4a4_row6_col9, #T_6e4a4_row14_col6 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_6e4a4_row4_col7, #T_6e4a4_row15_col11 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_6e4a4_row4_col8, #T_6e4a4_row4_col15, #T_6e4a4_row13_col15 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_6e4a4_row4_col10, #T_6e4a4_row13_col10, #T_6e4a4_row14_col15, #T_6e4a4_row16_col13, #T_6e4a4_row16_col15, #T_6e4a4_row17_col15 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_6e4a4_row4_col11 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_6e4a4_row4_col13, #T_6e4a4_row9_col1, #T_6e4a4_row10_col8 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_6e4a4_row4_col14, #T_6e4a4_row13_col12, #T_6e4a4_row16_col0, #T_6e4a4_row16_col17, #T_6e4a4_row17_col14 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_6e4a4_row4_col17, #T_6e4a4_row8_col3 {
#   background-co

# %% [markdown]
# It looks like following data (columns) have very low relevance (<10%) to dying from Covid (column "DEATH"):
# - SEX
# - PREGNANT
# - COPD (patient has Chronic obstructive pulmonary disease or not)
# - ASTHMA
# - INMSUPR (patient is immunosuppressed or not)
# - OTHER_DISEASE
# - TOBACCO
# - OBESITY
# - CARDIOVASCULAR
#
# Also, column "MEDICAL_UNIT" is irrelevant to me - it codes information about medical units from Mexican NHS.
# These columns will be dropped.

# %%
irrelevant_cols = ["SEX", "PREGNANT", "COPD", "ASTHMA", "INMSUPR", "OTHER_DISEASE", "TOBACCO", "OBESITY",
                   "CARDIOVASCULAR", "MEDICAL_UNIT"]
df.drop(columns=irrelevant_cols, inplace=True)

# %%
df.head()
# Out:
#    USMER  PATIENT_TYPE  PNEUMONIA  AGE  DIABETES  HIPERTENSION  RENAL_CHRONIC  \
# 0      2             1          1   65         2             1              2
# 1      2             1          1   72         2             1              1
# 2      2             2          2   55         1             2              2
# 3      2             1          2   53         2             2              2
# 4      2             1          2   68         1             1              2
#
#    CLASIFFICATION_FINAL  DEATH
# 0                     3      2
# 1                     5      2
# 2                     3      2
# 3                     7      2
# 4                     3      2

# %% [markdown]
# ##### 1 target column "DEATH", 8 feature columns.
#
# Column "CLASSIFICATION_FINAL" will be simplified to 1 - covid not diagnosed, 2 - covid diagnosed.

# %%
df["CLASIFFICATION_FINAL"] = [1 if clsf > 3 else 2 for clsf in df.CLASIFFICATION_FINAL]

# %%
df.head()
# Out:
#    USMER  PATIENT_TYPE  PNEUMONIA  AGE  DIABETES  HIPERTENSION  RENAL_CHRONIC  \
# 0      2             1          1   65         2             1              2
# 1      2             1          1   72         2             1              1
# 2      2             2          2   55         1             2              2
# 3      2             1          2   53         2             2              2
# 4      2             1          2   68         1             1              2
#
#    CLASIFFICATION_FINAL  DEATH
# 0                     2      2
# 1                     1      2
# 2                     2      2
# 3                     1      2
# 4                     2      2

# %%
for i in df.columns:
    print(i, "=>", len(df[i].unique()))
# Out:
# USMER => 2
# PATIENT_TYPE => 2
# PNEUMONIA => 2
# AGE => 121
# DIABETES => 2
# HIPERTENSION => 2
# RENAL_CHRONIC => 2
# CLASIFFICATION_FINAL => 2
# DEATH => 2

# %% [markdown]
# Now all binary values will be mapped to 0-1.

# %%
cols = df.columns.copy()
cols = cols.drop("AGE")

for i in cols:
    print(i, "=>", df[i].unique())
# Out:
# USMER => [2 1]
# PATIENT_TYPE => [1 2]
# PNEUMONIA => [1 2]
# DIABETES => [2 1]
# HIPERTENSION => [1 2]
# RENAL_CHRONIC => [2 1]
# CLASIFFICATION_FINAL => [2 1]
# DEATH => [2 1]

# %%
for col in cols:
    df[col] = [0 if row == 1 else 1 for row in df[col]]

df.head()
# Out:
#    USMER  PATIENT_TYPE  PNEUMONIA  AGE  DIABETES  HIPERTENSION  RENAL_CHRONIC  \
# 0      1             0          0   65         1             0              1
# 1      1             0          0   72         1             0              0
# 2      1             1          1   55         0             1              1
# 3      1             0          1   53         1             1              1
# 4      1             0          1   68         0             0              1
#
#    CLASIFFICATION_FINAL  DEATH
# 0                     1      1
# 1                     0      1
# 2                     1      1
# 3                     0      1
# 4                     1      1

# %%
for i in df.columns:
    print(i, "=>", df[i].unique())
# Out:
# USMER => [1 0]
# PATIENT_TYPE => [0 1]
# PNEUMONIA => [0 1]
# AGE => [ 65  72  55  53  68  40  64  37  25  38  24  30  48  23  80  61  54  59
#   45  26  32  49  39  27  57  20  56  47  50  46  43  28  33  16  62  58
#   36  44  66  52  51  35  19  90  34  22  29  14  31  42  15   0  17  41
#    2  10   1  12   4   7   6   8  60   5  13  63  75  81  67  18  70  88
#   85  92  73  74  78  76  82  77  86  71  95  87  83  84  79  69  89   3
#   97  93 100  91  21 103  11   9  94  96 101 107 102  98  99 109 116 105
#  111 104 114 120 106 110 118 117 121 108 115 119 113]
# DIABETES => [1 0]
# HIPERTENSION => [0 1]
# RENAL_CHRONIC => [1 0]
# CLASIFFICATION_FINAL => [1 0]
# DEATH => [1 0]

# %%
# Rename columns to less medical terms.
df["COVID"] = df["CLASIFFICATION_FINAL"]
df["HOSPITALIZED"] = df["PATIENT_TYPE"]
df["RENAL"] = df["RENAL_CHRONIC"]
df["MEDICAL_CARE"] = df["USMER"]

df.drop(["CLASIFFICATION_FINAL", "PATIENT_TYPE", "RENAL_CHRONIC", "USMER"], axis=1, inplace=True)

df.head()
# Out:
#    PNEUMONIA  AGE  DIABETES  HIPERTENSION  DEATH  COVID  HOSPITALIZED  RENAL  \
# 0          0   65         1             0      1      1             0      1
# 1          0   72         1             0      1      0             0      0
# 2          1   55         0             1      1      1             1      1
# 3          1   53         1             1      1      0             0      1
# 4          1   68         0             0      1      1             0      1
#
#    MEDICAL_CARE
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1

# %% [markdown]
# Data is preprecessed and ready to classification.

# %%
y = df["DEATH"]
cols = df.columns.drop("DEATH")
X = df[cols]

# %%
X
# Out:
#          PNEUMONIA  AGE  DIABETES  HIPERTENSION  COVID  HOSPITALIZED  RENAL  \
# 0                0   65         1             0      1             0      1
# 1                0   72         1             0      0             0      0
# 2                1   55         0             1      1             1      1
# 3                1   53         1             1      0             0      1
# 4                1   68         0             0      1             0      1
# ...            ...  ...       ...           ...    ...           ...    ...
# 1048570          1   40         1             1      0             0      1
# 1048571          1   51         1             0      0             1      1
# 1048572          1   55         1             1      0             0      1
# 1048573          1   28         1             1      0             0      1
# 1048574          1   52         1             1      0             0      1
#
#          MEDICAL_CARE
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 1048570             1
# 1048571             0
# 1048572             1
# 1048573             1
# 1048574             1
#
# [1021977 rows x 8 columns]

# %%
y
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 1048570    0
# 1048571    0
# 1048572    0
# 1048573    0
# 1048574    0
# Name: DEATH, Length: 1021977, dtype: int64
